# %% [markdown]
# ## Import....

# %%
import numpy as np
import pandas as pd

# %%
df_horse = pd.read_csv('../data/horse.csv')

# %% [markdown]
# ## Data

# %%
df_horse.head()
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 9        no  young          5299629         38.3   90.0              25.0
# 168     yes  adult           535085         38.2   65.0              24.0
# 266      no  adult           527829         38.3   54.0              18.0
# 127     yes  adult          5262541         37.4   50.0              32.0
# 181     yes  adult          5279822         38.0   64.0              24.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 9                normal           normal     normal_pink
# 168                cool           normal     normal_pink
# 266                cool           normal     bright_pink
# 127                cool          reduced     normal_pink
# 181                cool          reduced   dark_cyanotic
#
#     capillary_refill_time   ...    packed_cell_volume total_protein  \
# 9              less_3_sec   ...                  40.0           6.2
# 168            more_3_sec   ...                  45.0           7.5
# 266            less_3_sec   ...                  44.0           7.2
# 127            less_3_sec   ...                  45.0           7.9
# 181            more_3_sec   ...                  68.0           7.8
#
#     abdomo_appearance abdomo_protein     outcome  surgical_lesion lesion_1  \
# 9               clear            2.2       lived               no        0
# 168            cloudy            2.3  euthanized              yes     3205
# 266     serosanguious            2.3       lived               no     2124
# 127            cloudy            1.0       lived              yes     2208
# 181            cloudy            2.3        died              yes     2205
#
#     lesion_2  lesion_3  cp_data
# 9          0         0      yes
# 168        0         0       no
# 266        0         0      yes
# 127        0         0      yes
# 181        0         0       no
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Get median & mode
# * String: mode
# * Numeric: median

# %%
df_horse.columns
# Out:
# Index(['surgery', 'age', 'hospital_number', 'rectal_temp', 'pulse',
#        'respiratory_rate', 'temp_of_extremities', 'peripheral_pulse',
#        'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis',
#        'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux',
#        'nasogastric_reflux_ph', 'rectal_exam_feces', 'abdomen',
#        'packed_cell_volume', 'total_protein', 'abdomo_appearance',
#        'abdomo_protein', 'outcome', 'surgical_lesion', 'lesion_1', 'lesion_2',
#        'lesion_3', 'cp_data'],
#       dtype='object')

# %%
dict_column_median_mode = {}

for column in df_horse.columns:
    df_horse_drop_nan_row = df_horse[column].dropna()
    
    if isinstance(df_horse_drop_nan_row.values[0], str):
        dict_column_median_mode[column] = df_horse_drop_nan_row.mode()[0]
    else:
        dict_column_median_mode[column] = df_horse_drop_nan_row.median()

# %%
dict_column_median_mode
# Out:
# {'surgery': 'yes',
#  'age': 'adult',
#  'hospital_number': 530301.0,
#  'rectal_temp': 38.2,
#  'pulse': 64.0,
#  'respiratory_rate': 25.0,
#  'temp_of_extremities': 'cool',
#  'peripheral_pulse': 'normal',
#  'mucous_membrane': 'normal_pink',
#  'capillary_refill_time': 'less_3_sec',
#  'pain': 'mild_pain',
#  'peristalsis': 'hypomotile',
#  'abdominal_distention': 'none',
#  'nasogastric_tube': 'slight',
#  'nasogastric_reflux': 'none',
#  'nasogastric_reflux_ph': 5.0,
#  'rectal_exam_feces': 'absent',
#  'abdomen': 'distend_large',
#  'packed_cell_volume': 45.0,
#  'total_protein': 7.5,
#  'abdomo_appearance': 'cloudy',
#  'abdomo_protein': 2.3,
#  'outcome': 'lived',
#  'surgical_lesion': 'yes',
#  'lesion_1': 2322.0,
#  'lesion_2': 0.0,
#  'lesion_3': 0.0,
#  'cp_data': 'no'}

# %% [markdown]
# ## Fill Nan with median & mode
# * String: mode
# * Numeric: median

# %%
for column in df_horse.columns:
    df_horse[column].fillna(dict_column_median_mode[column], inplace = True)

# %%
df_horse.head(20)
# Out:
#    surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0       no  adult           530101         38.5   66.0              28.0
# 1      yes  adult           534817         39.2   88.0              20.0
# 2       no  adult           530334         38.3   40.0              24.0
# 3      yes  young          5290409         39.1  164.0              84.0
# 4       no  adult           530255         37.3  104.0              35.0
# 5       no  adult           528355         38.2   64.0              25.0
# 6      yes  adult           526802         37.9   48.0              16.0
# 7      yes  adult           529607         38.2   60.0              25.0
# 8       no  adult           530051         38.2   80.0              36.0
# 9       no  young          5299629         38.3   90.0              25.0
# 10     yes  adult           528548         38.1   66.0              12.0
# 11      no  adult           527927         39.1   72.0              52.0
# 12     yes  adult           528031         37.2   42.0              12.0
# 13      no  young          5291329         38.0   92.0              28.0
# 14     yes  adult           534917         38.2   76.0              28.0
# 15     yes  adult           530233         37.6   96.0              48.0
# 16     yes  young          5301219         38.2  128.0              36.0
# 17      no  adult           526639         37.5   48.0              24.0
# 18     yes  adult          5290481         37.6   64.0              21.0
# 19      no  adult           532110         39.4  110.0              35.0
#
#    temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                 cool          reduced     normal_pink            more_3_sec
# 1                 cool           normal   pale_cyanotic            less_3_sec
# 2               normal           normal       pale_pink            less_3_sec
# 3                 cold           normal   dark_cyanotic            more_3_sec
# 4                 cool           normal   dark_cyanotic            more_3_sec
# 5                 warm           normal       pale_pink            less_3_sec
# 6               normal           normal     normal_pink            less_3_sec
# 7                 cool           normal     normal_pink            less_3_sec
# 8                 cool           absent       pale_pink            less_3_sec
# 9               normal           normal     normal_pink            less_3_sec
# 10                cool          reduced      bright_red            less_3_sec
# 11                warm           normal     bright_pink            less_3_sec
# 12                warm           normal     normal_pink            less_3_sec
# 13              normal           normal     bright_pink            less_3_sec
# 14                cool           normal     normal_pink            less_3_sec
# 15                cool           normal   pale_cyanotic            less_3_sec
# 16                cool          reduced   pale_cyanotic            more_3_sec
# 17                cool           normal     normal_pink            less_3_sec
# 18              normal           normal     bright_pink            less_3_sec
# 19                cold          reduced   dark_cyanotic            less_3_sec
#
#      ...    packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0    ...                  45.0           8.4            cloudy            2.3
# 1    ...                  50.0          85.0            cloudy            2.0
# 2    ...                  33.0           6.7            cloudy            2.3
# 3    ...                  48.0           7.2     serosanguious            5.3
# 4    ...                  74.0           7.4            cloudy            2.3
# 5    ...                  45.0           7.5            cloudy            2.3
# 6    ...                  37.0           7.0            cloudy            2.3
# 7    ...                  44.0           8.3            cloudy            2.3
# 8    ...                  38.0           6.2            cloudy            2.3
# 9    ...                  40.0           6.2             clear            2.2
# 10   ...                  44.0           6.0            cloudy            3.6
# 11   ...                  50.0           7.8            cloudy            2.3
# 12   ...                  45.0           7.0            cloudy            2.3
# 13   ...                  37.0           6.1             clear            2.3
# 14   ...                  46.0          81.0             clear            2.0
# 15   ...                  45.0           6.8            cloudy            2.3
# 16   ...                  53.0           7.8     serosanguious            4.7
# 17   ...                  45.0           7.5            cloudy            2.3
# 18   ...                  40.0           7.0             clear            2.3
# 19   ...                  55.0           8.7            cloudy            2.3
#
#        outcome  surgical_lesion lesion_1 lesion_2  lesion_3  cp_data
# 0         died               no    11300        0         0       no
# 1   euthanized               no     2208        0         0       no
# 2        lived               no        0        0         0      yes
# 3         died              yes     2208        0         0      yes
# 4         died               no     4300        0         0       no
# 5        lived               no        0        0         0       no
# 6        lived              yes     3124        0         0       no
# 7         died              yes     2208        0         0       no
# 8   euthanized              yes     3205        0         0       no
# 9        lived               no        0        0         0      yes
# 10       lived              yes     2124        0         0      yes
# 11       lived              yes     2111        0         0       no
# 12       lived               no     4124        0         0       no
# 13        died               no        0        0         0      yes
# 14       lived              yes     2112        0         0       no
# 15        died              yes     3207        0         0       no
# 16        died               no     1400        0         0      yes
# 17       lived               no        0        0         0       no
# 18       lived              yes     4205        0         0      yes
# 19       lived               no        0        0         0       no
#
# [20 rows x 28 columns]

# %% [markdown]
# ## Check if everything is not nan

# %%
dict_col_null_count = {}

# %%
for column in df_horse.columns:
    dict_col_null_count[column] = len(df_horse) - df_horse[column].isnull().sum()

# %%
dict_col_null_count
# Out:
# {'surgery': 299,
#  'age': 299,
#  'hospital_number': 299,
#  'rectal_temp': 299,
#  'pulse': 299,
#  'respiratory_rate': 299,
#  'temp_of_extremities': 299,
#  'peripheral_pulse': 299,
#  'mucous_membrane': 299,
#  'capillary_refill_time': 299,
#  'pain': 299,
#  'peristalsis': 299,
#  'abdominal_distention': 299,
#  'nasogastric_tube': 299,
#  'nasogastric_reflux': 299,
#  'nasogastric_reflux_ph': 299,
#  'rectal_exam_feces': 299,
#  'abdomen': 299,
#  'packed_cell_volume': 299,
#  'total_protein': 299,
#  'abdomo_appearance': 299,
#  'abdomo_protein': 299,
#  'outcome': 299,
#  'surgical_lesion': 299,
#  'lesion_1': 299,
#  'lesion_2': 299,
#  'lesion_3': 299,
#  'cp_data': 299}

# %% [markdown]
# ## String to get_dummies

# %%
df_horse = df_horse.reindex(np.random.permutation(df_horse.index))

# %%
df_horse.head(20)
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 9        no  young          5299629         38.3   90.0              25.0
# 168     yes  adult           535085         38.2   65.0              24.0
# 266      no  adult           527829         38.3   54.0              18.0
# 127     yes  adult          5262541         37.4   50.0              32.0
# 181     yes  adult          5279822         38.0   64.0              24.0
# 255     yes  adult           533871         37.5   72.0              25.0
# 59       no  adult           528904         38.2   96.0              25.0
# 111     yes  adult           533736         38.3   40.0              16.0
# 117      no  adult          5290482         39.5   64.0              25.0
# 137      no  adult           532349         38.0   56.0              25.0
# 200     yes  adult           528641         38.5   86.0              25.0
# 243     yes  young          5291409         38.2  124.0              88.0
# 160     yes  adult           530431         38.3   42.0              24.0
# 87       no  adult           528006         38.2   40.0              16.0
# 279     yes  adult           534644         38.6   48.0              12.0
# 51      yes  adult           527706         37.4   84.0              36.0
# 5        no  adult           528355         38.2   64.0              25.0
# 90       no  adult           534197         38.0   52.0              16.0
# 91       no  adult           529461         40.3  114.0              36.0
# 190      no  young          5287279         38.2  100.0              44.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 9                normal           normal     normal_pink
# 168                cool           normal     normal_pink
# 266                cool           normal     bright_pink
# 127                cool          reduced     normal_pink
# 181                cool          reduced   dark_cyanotic
# 255                warm           normal     normal_pink
# 59                 cool          reduced       pale_pink
# 111                cool           normal     normal_pink
# 117                cool          reduced   pale_cyanotic
# 137              normal        increased       pale_pink
# 200              normal           normal       pale_pink
# 243              normal          reduced     bright_pink
# 160                cool           normal     normal_pink
# 87                 cool           normal     normal_pink
# 279                cool           normal     normal_pink
# 51               normal           normal       pale_pink
# 5                  warm           normal       pale_pink
# 90                 cool           normal     normal_pink
# 91                 cool          reduced     normal_pink
# 190                warm           normal     normal_pink
#
#     capillary_refill_time   ...    packed_cell_volume total_protein  \
# 9              less_3_sec   ...                  40.0           6.2
# 168            more_3_sec   ...                  45.0           7.5
# 266            less_3_sec   ...                  44.0           7.2
# 127            less_3_sec   ...                  45.0           7.9
# 181            more_3_sec   ...                  68.0           7.8
# 255            less_3_sec   ...                  35.0          65.0
# 59             more_3_sec   ...                  60.0           7.5
# 111            less_3_sec   ...                  38.0          58.0
# 117            more_3_sec   ...                  45.0           6.7
# 137            less_3_sec   ...                  42.0          71.0
# 200            less_3_sec   ...                  45.0           7.4
# 243            less_3_sec   ...                  47.0           8.0
# 160            less_3_sec   ...                  40.0           8.5
# 87             less_3_sec   ...                  50.0           7.0
# 279            less_3_sec   ...                  36.0          67.0
# 51             more_3_sec   ...                  45.0           7.5
# 5              less_3_sec   ...                  45.0           7.5
# 90             less_3_sec   ...                  53.0          86.0
# 91             more_3_sec   ...                  57.0           8.1
# 190            less_3_sec   ...                  37.0           4.7
#
#     abdomo_appearance abdomo_protein     outcome  surgical_lesion lesion_1  \
# 9               clear            2.2       lived               no        0
# 168            cloudy            2.3  euthanized              yes     3205
# 266     serosanguious            2.3       lived               no     2124
# 127            cloudy            1.0       lived              yes     2208
# 181            cloudy            2.3        died              yes     2205
# 255            cloudy            2.0  euthanized              yes     7209
# 59             cloudy            2.3        died              yes     4205
# 111             clear            2.0       lived              yes     3111
# 117             clear            2.3  euthanized              yes     4205
# 137            cloudy            2.3       lived               no        0
# 200             clear            3.4        died              yes     3209
# 243             clear            2.3       lived              yes     9400
# 160            cloudy            2.3        died              yes     7113
# 87             cloudy            3.9  euthanized              yes     2208
# 279            cloudy            2.3       lived               no        0
# 51      serosanguious            2.3        died              yes     7209
# 5              cloudy            2.3       lived               no        0
# 90             cloudy            2.3       lived              yes     2322
# 91      serosanguious            4.5        died              yes     3205
# 190            cloudy            2.3       lived               no     7111
#
#     lesion_2  lesion_3  cp_data
# 9          0         0      yes
# 168        0         0       no
# 266        0         0      yes
# 127        0         0      yes
# 181        0         0       no
# 255        0         0       no
# 59         0         0       no
# 111     7111         0       no
# 117        0         0       no
# 137        0         0       no
# 200        0         0      yes
# 243        0         0      yes
# 160        0         0       no
# 87         0         0      yes
# 279        0         0       no
# 51         0         0      yes
# 5          0         0       no
# 90         0         0       no
# 91         0         0      yes
# 190        0         0       no
#
# [20 rows x 28 columns]

# %%
df_horse_one_hot = pd.get_dummies(df_horse.drop(columns = ['outcome']))

# %%
df_horse_one_hot.head()
# Out:
#      hospital_number  rectal_temp  pulse  respiratory_rate  \
# 9            5299629         38.3   90.0              25.0
# 168           535085         38.2   65.0              24.0
# 266           527829         38.3   54.0              18.0
# 127          5262541         37.4   50.0              32.0
# 181          5279822         38.0   64.0              24.0
#
#      nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 9                      5.0                40.0            6.2             2.2
# 168                    5.0                45.0            7.5             2.3
# 266                    5.4                44.0            7.2             2.3
# 127                    5.0                45.0            7.9             1.0
# 181                    5.0                68.0            7.8             2.3
#
#      lesion_1  lesion_2     ...       abdomen_firm  abdomen_normal  \
# 9           0         0     ...                  0               0
# 168      3205         0     ...                  0               0
# 266      2124         0     ...                  0               0
# 127      2208         0     ...                  0               0
# 181      2205         0     ...                  0               0
#
#      abdomen_other  abdomo_appearance_clear  abdomo_appearance_cloudy  \
# 9                0                        1                         0
# 168              0                        0                         1
# 266              0                        0                         0
# 127              0                        0                         1
# 181              0                        0                         1
#
#      abdomo_appearance_serosanguious  surgical_lesion_no  surgical_lesion_yes  \
# 9                                  0                   1                    0
# 168                                0                   0                    1
# 266                                1                   1                    0
# 127                                0                   0                    1
# 181                                0                   0                    1
#
#      cp_data_no  cp_data_yes
# 9             0            1
# 168           1            0
# 266           0            1
# 127           0            1
# 181           1            0
#
# [5 rows x 67 columns]

# %%
X = df_horse_one_hot

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
le.fit(df_horse['outcome'])
# Out:
# LabelEncoder()

# %% [markdown]
# * Lived: 1
# * euthanized: 0
# * Died: -1

# %%
y = le.transform(df_horse['outcome']) - 1

# %% [markdown]
# ## Run ML

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB

# %%
names = ["OneR", "Nearest Neighbors", "Linear SVM", "RBF SVM",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost", "Naive Bayes"]

# %%
classifiers = [
    DecisionTreeClassifier(max_depth=1),
    KNeighborsClassifier(5),
    SVC(kernel="linear", C=0.025),
    SVC(kernel="rbf", C=0.025),
    DecisionTreeClassifier(max_depth=10),
    RandomForestClassifier(max_depth=10, n_estimators=300),
    MLPClassifier(alpha=1, hidden_layer_sizes = (100, 50)),
    AdaBoostClassifier(n_estimators = 300),
    GaussianNB()]

# %% [markdown]
# ## CV

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import precision_recall_fscore_support

# %%
evaluations = []

for name, clf in zip(names, classifiers):
    y_pred = cross_val_predict(clf, X, y, cv = 10)
    print(len(y_pred))
    
    precision_recall_f1 = precision_recall_fscore_support(y, y_pred, average='weighted')
    scores = cross_validate(clf, X, y, cv = 10)
    print(scores['test_score'])
    
    evaluations.append([name, scores['test_score'].mean(), precision_recall_f1[:3]])
# Out:
# 299
# [0.64516129 0.58064516 0.67741935 0.67741935 0.6        0.6
#  0.66666667 0.62068966 0.53571429 0.60714286]
# 299
# [0.58064516 0.67741935 0.5483871  0.74193548 0.56666667 0.63333333
#  0.56666667 0.62068966 0.60714286 0.64285714]
# C:\Users\JSY\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 299
# C:\Users\JSY\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [0.58064516 0.61290323 0.58064516 0.58064516 0.6        0.56666667
#  0.6        0.5862069  0.64285714 0.57142857]
# 299
# C:\Users\JSY\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [0.58064516 0.58064516 0.58064516 0.58064516 0.6        0.6
#  0.6        0.62068966 0.60714286 0.60714286]
# 299
# [0.48387097 0.64516129 0.67741935 0.5483871  0.66666667 0.56666667
#  0.7        0.55172414 0.60714286 0.64285714]
# 299
# [0.61290323 0.74193548 0.67741935 0.64516129 0.76666667 0.7
#  0.66666667 0.75862069 0.78571429 0.60714286]
# 299
# C:\Users\JSY\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [0.58064516 0.61290323 0.25806452 0.58064516 0.6        0.26666667
#  0.26666667 0.62068966 0.14285714 0.25      ]
# 299
# [0.67741935 0.64516129 0.64516129 0.5483871  0.63333333 0.66666667
#  0.56666667 0.65517241 0.64285714 0.57142857]
# 299
# [0.29032258 0.22580645 0.32258065 0.29032258 0.4        0.26666667
#  0.33333333 0.37931034 0.21428571 0.28571429]

# %% [markdown]
# ## Result

# %%
evaluations.sort(key = lambda evaluations: evaluations[1])
evaluations.reverse()

# %%
for evaluation in evaluations:
    print("-----" * 5)
    print(evaluation[0])
    print("Accuracy: ", evaluation[1])
    if len(evaluation) > 2: print("Precision, Recall, F1", evaluation[2])
    print("-----" * 5, end = "\n\n")
# Out:
# -------------------------
# Random Forest
# Accuracy:  0.6962230520684358
# Precision, Recall, F1 (0.6954915838934158, 0.7123745819397993, 0.6867427120262534)
# -------------------------
#
# -------------------------
# AdaBoost
# Accuracy:  0.6252253827003549
# Precision, Recall, F1 (0.6264303223366855, 0.6254180602006689, 0.6253384666942932)
# -------------------------
#
# -------------------------
# OneR
# Accuracy:  0.6210858625986545
# Precision, Recall, F1 (0.5103175320566625, 0.6220735785953178, 0.5403207612249192)
# -------------------------
#
# -------------------------
# Nearest Neighbors
# Accuracy:  0.6185743418613274
# Precision, Recall, F1 (0.6147472858552803, 0.6187290969899666, 0.6125909455987798)
# -------------------------
#
# -------------------------
# Decision Tree
# Accuracy:  0.6089896180941787
# Precision, Recall, F1 (0.6344168671399794, 0.6387959866220736, 0.6362089528222797)
# -------------------------
#
# -------------------------
# RBF SVM
# Accuracy:  0.5957556014619417
# Precision, Recall, F1 (0.3544031945951388, 0.5953177257525084, 0.4443042146077421)
# -------------------------
#
# -------------------------
# Linear SVM
# Accuracy:  0.5921997987181524
# Precision, Recall, F1 (0.45736582258321384, 0.5919732441471572, 0.45400542804248967)
# -------------------------
#
# -------------------------
# Neural Net
# Accuracy:  0.41791381958790197
# Precision, Recall, F1 (0.41983963332728785, 0.5284280936454849, 0.4635783203802296)
# -------------------------
#
# -------------------------
# Naive Bayes
# Accuracy:  0.30083426028921023
# Precision, Recall, F1 (0.5169689280001153, 0.3010033444816054, 0.19538849740158326)
# -------------------------

# %%
df_horse.head()
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 9        no  young          5299629         38.3   90.0              25.0
# 168     yes  adult           535085         38.2   65.0              24.0
# 266      no  adult           527829         38.3   54.0              18.0
# 127     yes  adult          5262541         37.4   50.0              32.0
# 181     yes  adult          5279822         38.0   64.0              24.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 9                normal           normal     normal_pink
# 168                cool           normal     normal_pink
# 266                cool           normal     bright_pink
# 127                cool          reduced     normal_pink
# 181                cool          reduced   dark_cyanotic
#
#     capillary_refill_time   ...    packed_cell_volume total_protein  \
# 9              less_3_sec   ...                  40.0           6.2
# 168            more_3_sec   ...                  45.0           7.5
# 266            less_3_sec   ...                  44.0           7.2
# 127            less_3_sec   ...                  45.0           7.9
# 181            more_3_sec   ...                  68.0           7.8
#
#     abdomo_appearance abdomo_protein     outcome  surgical_lesion lesion_1  \
# 9               clear            2.2       lived               no        0
# 168            cloudy            2.3  euthanized              yes     3205
# 266     serosanguious            2.3       lived               no     2124
# 127            cloudy            1.0       lived              yes     2208
# 181            cloudy            2.3        died              yes     2205
#
#     lesion_2  lesion_3  cp_data
# 9          0         0      yes
# 168        0         0       no
# 266        0         0      yes
# 127        0         0      yes
# 181        0         0       no
#
# [5 rows x 28 columns]

# %% [markdown]
# # hospital number

# %%
len(df_horse['hospital_number'].unique()) #hospital number가 unique한 값인지
# Out:
# 283

# %%
df_horse['hospital_number'].count()
# Out:
# 299

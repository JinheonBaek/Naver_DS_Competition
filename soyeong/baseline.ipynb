# %% [markdown]
# ## Import....

# %%
import numpy as np
import pandas as pd

# %%
df_horse = pd.read_csv('../data/horse.csv')

# %% [markdown]
# ## Data

# %%
df_horse.head()
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 218     yes  adult           529736         38.2   52.0              28.0
# 129     yes  adult           527698         38.4   49.0              25.0
# 76      yes  adult           534615         37.6   38.0              20.0
# 20      yes  adult           530157         39.9   72.0              60.0
# 148      no  adult           535314         38.7   48.0              24.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 218                cool          reduced   pale_cyanotic
# 129                cool           normal     normal_pink
# 76                 cool          reduced     normal_pink
# 20               normal           normal      bright_red
# 148                cool           normal     normal_pink
#
#     capillary_refill_time   ...    packed_cell_volume total_protein  \
# 218            less_3_sec   ...                  37.0           8.1
# 129            less_3_sec   ...                  44.0           7.6
# 76             less_3_sec   ...                  37.0          68.0
# 20             more_3_sec   ...                  46.0           6.1
# 148            less_3_sec   ...                  34.0          63.0
#
#     abdomo_appearance abdomo_protein outcome  surgical_lesion lesion_1  \
# 218            cloudy            2.3   lived              yes     2111
# 129            cloudy            2.3   lived              yes     2206
# 76             cloudy            2.3   lived              yes     3205
# 20             cloudy            2.3   lived              yes     2111
# 148            cloudy            2.3   lived               no        0
#
#     lesion_2  lesion_3  cp_data
# 218        0         0       no
# 129        0         0       no
# 76         0         0       no
# 20         0         0       no
# 148        0         0       no
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Get median & mode
# * String: mode
# * Numeric: median

# %%
df_horse.columns
# Out:
# Index(['surgery', 'age', 'hospital_number', 'rectal_temp', 'pulse',
#        'respiratory_rate', 'temp_of_extremities', 'peripheral_pulse',
#        'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis',
#        'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux',
#        'nasogastric_reflux_ph', 'rectal_exam_feces', 'abdomen',
#        'packed_cell_volume', 'total_protein', 'abdomo_appearance',
#        'abdomo_protein', 'outcome', 'surgical_lesion', 'lesion_1', 'lesion_2',
#        'lesion_3', 'cp_data'],
#       dtype='object')

# %%
dict_column_median_mode = {}

for column in df_horse.columns:
    df_horse_drop_nan_row = df_horse[column].dropna()
    
    if isinstance(df_horse_drop_nan_row.values[0], str):
        dict_column_median_mode[column] = df_horse_drop_nan_row.mode()[0]
    else:
        dict_column_median_mode[column] = df_horse_drop_nan_row.median()

# %%
dict_column_median_mode
# Out:
# {'surgery': 'yes',
#  'age': 'adult',
#  'hospital_number': 530301.0,
#  'rectal_temp': 38.2,
#  'pulse': 64.0,
#  'respiratory_rate': 25.0,
#  'temp_of_extremities': 'cool',
#  'peripheral_pulse': 'normal',
#  'mucous_membrane': 'normal_pink',
#  'capillary_refill_time': 'less_3_sec',
#  'pain': 'mild_pain',
#  'peristalsis': 'hypomotile',
#  'abdominal_distention': 'none',
#  'nasogastric_tube': 'slight',
#  'nasogastric_reflux': 'none',
#  'nasogastric_reflux_ph': 5.0,
#  'rectal_exam_feces': 'absent',
#  'abdomen': 'distend_large',
#  'packed_cell_volume': 45.0,
#  'total_protein': 7.5,
#  'abdomo_appearance': 'cloudy',
#  'abdomo_protein': 2.3,
#  'outcome': 'lived',
#  'surgical_lesion': 'yes',
#  'lesion_1': 2322.0,
#  'lesion_2': 0.0,
#  'lesion_3': 0.0,
#  'cp_data': 'no'}

# %% [markdown]
# ## Fill Nan with median & mode
# * String: mode
# * Numeric: median

# %%
for column in df_horse.columns:
    df_horse[column].fillna(dict_column_median_mode[column], inplace = True)

# %%
df_horse.head(20)
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 218     yes  adult           529736         38.2   52.0              28.0
# 129     yes  adult           527698         38.4   49.0              25.0
# 76      yes  adult           534615         37.6   38.0              20.0
# 20      yes  adult           530157         39.9   72.0              60.0
# 148      no  adult           535314         38.7   48.0              24.0
# 243     yes  young          5291409         38.2  124.0              88.0
# 261      no  young          5305629         38.6   88.0              28.0
# 229     yes  adult           534280         38.5  104.0              40.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 281     yes  adult           527544         38.2   70.0              16.0
# 262     yes  adult           528743         37.1   75.0              36.0
# 28      yes  adult          5279442         38.2   64.0              25.0
# 207     yes  adult           535338         37.8   88.0              80.0
# 174     yes  adult           527929         38.2   64.0              25.0
# 26      yes  adult           530526         38.3   72.0              30.0
# 121     yes  adult           534556         38.3   80.0              40.0
# 74      yes  young          5292929         38.2   64.0              25.0
# 10      yes  adult           528548         38.1   66.0              12.0
# 216     yes  adult          5279441         38.0   76.0              18.0
# 214     yes  adult           529135         37.8   40.0              12.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 218                cool          reduced   pale_cyanotic
# 129                cool           normal     normal_pink
# 76                 cool          reduced     normal_pink
# 20               normal           normal      bright_red
# 148                cool           normal     normal_pink
# 243              normal          reduced     bright_pink
# 261                cool           normal     normal_pink
# 229                cool          reduced     normal_pink
# 3                  cold           normal   dark_cyanotic
# 281                cool           absent      bright_red
# 262                cool           normal       pale_pink
# 28                 cool           normal     normal_pink
# 207                cool          reduced      bright_red
# 174                cool           normal     normal_pink
# 26                 cold          reduced       pale_pink
# 121                cool           normal   dark_cyanotic
# 74                 cool           normal     normal_pink
# 10                 cool          reduced      bright_red
# 216                cool           normal     normal_pink
# 214              normal           normal     normal_pink
#
#     capillary_refill_time   ...    packed_cell_volume total_protein  \
# 218            less_3_sec   ...                  37.0           8.1
# 129            less_3_sec   ...                  44.0           7.6
# 76             less_3_sec   ...                  37.0          68.0
# 20             more_3_sec   ...                  46.0           6.1
# 148            less_3_sec   ...                  34.0          63.0
# 243            less_3_sec   ...                  47.0           8.0
# 261            less_3_sec   ...                  35.0           5.9
# 229            less_3_sec   ...                  45.0           7.5
# 3              more_3_sec   ...                  48.0           7.2
# 281            more_3_sec   ...                  60.0           7.5
# 262            more_3_sec   ...                  48.0           7.4
# 28             less_3_sec   ...                  45.0           7.5
# 207            more_3_sec   ...                  64.0          89.0
# 174            less_3_sec   ...                  45.0           7.5
# 26             more_3_sec   ...                  43.0           7.0
# 121            more_3_sec   ...                  67.0          10.2
# 74             less_3_sec   ...                  37.0           4.9
# 10             less_3_sec   ...                  44.0           6.0
# 216            more_3_sec   ...                  71.0          11.0
# 214            less_3_sec   ...                  38.0           7.0
#
#     abdomo_appearance abdomo_protein     outcome  surgical_lesion lesion_1  \
# 218            cloudy            2.3       lived              yes     2111
# 129            cloudy            2.3       lived              yes     2206
# 76             cloudy            2.3       lived              yes     3205
# 20             cloudy            2.3       lived              yes     2111
# 148            cloudy            2.3       lived               no        0
# 243             clear            2.3       lived              yes     9400
# 261            cloudy            2.3       lived               no        0
# 229            cloudy            2.3       lived              yes     2124
# 3       serosanguious            5.3        died              yes     2208
# 281            cloudy            2.3        died              yes     1400
# 262     serosanguious            3.2        died              yes    12208
# 28             cloudy            2.3        died               no     4300
# 207            cloudy            2.3  euthanized              yes     3205
# 174            cloudy            2.3       lived              yes     2208
# 26             cloudy            3.9       lived              yes     3111
# 121            cloudy            1.0  euthanized              yes     2208
# 74             cloudy            2.3        died              yes    11124
# 10             cloudy            3.6       lived              yes     2124
# 216            cloudy            2.3       lived              yes     2209
# 214            cloudy            2.3       lived              yes     3111
#
#     lesion_2  lesion_3  cp_data
# 218        0         0       no
# 129        0         0       no
# 76         0         0       no
# 20         0         0       no
# 148        0         0       no
# 243        0         0      yes
# 261        0         0       no
# 229        0         0       no
# 3          0         0      yes
# 281        0         0       no
# 262        0         0      yes
# 28         0         0       no
# 207        0         0       no
# 174        0         0       no
# 26         0         0      yes
# 121        0         0       no
# 74         0         0       no
# 10         0         0      yes
# 216        0         0      yes
# 214        0         0       no
#
# [20 rows x 28 columns]

# %% [markdown]
# ## Check if everything is not nan

# %%
dict_col_null_count = {}

# %%
for column in df_horse.columns:
    dict_col_null_count[column] = len(df_horse) - df_horse[column].isnull().sum()

# %%
dict_col_null_count
# Out:
# {'surgery': 299,
#  'age': 299,
#  'hospital_number': 299,
#  'rectal_temp': 299,
#  'pulse': 299,
#  'respiratory_rate': 299,
#  'temp_of_extremities': 299,
#  'peripheral_pulse': 299,
#  'mucous_membrane': 299,
#  'capillary_refill_time': 299,
#  'pain': 299,
#  'peristalsis': 299,
#  'abdominal_distention': 299,
#  'nasogastric_tube': 299,
#  'nasogastric_reflux': 299,
#  'nasogastric_reflux_ph': 299,
#  'rectal_exam_feces': 299,
#  'abdomen': 299,
#  'packed_cell_volume': 299,
#  'total_protein': 299,
#  'abdomo_appearance': 299,
#  'abdomo_protein': 299,
#  'outcome': 299,
#  'surgical_lesion': 299,
#  'lesion_1': 299,
#  'lesion_2': 299,
#  'lesion_3': 299,
#  'cp_data': 299}

# %% [markdown]
# ## String to get_dummies

# %%
df_horse = df_horse.reindex(np.random.permutation(df_horse.index))

# %%
df_horse.head(20)
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 218     yes  adult           529736         38.2   52.0              28.0
# 129     yes  adult           527698         38.4   49.0              25.0
# 76      yes  adult           534615         37.6   38.0              20.0
# 20      yes  adult           530157         39.9   72.0              60.0
# 148      no  adult           535314         38.7   48.0              24.0
# 243     yes  young          5291409         38.2  124.0              88.0
# 261      no  young          5305629         38.6   88.0              28.0
# 229     yes  adult           534280         38.5  104.0              40.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 281     yes  adult           527544         38.2   70.0              16.0
# 262     yes  adult           528743         37.1   75.0              36.0
# 28      yes  adult          5279442         38.2   64.0              25.0
# 207     yes  adult           535338         37.8   88.0              80.0
# 174     yes  adult           527929         38.2   64.0              25.0
# 26      yes  adult           530526         38.3   72.0              30.0
# 121     yes  adult           534556         38.3   80.0              40.0
# 74      yes  young          5292929         38.2   64.0              25.0
# 10      yes  adult           528548         38.1   66.0              12.0
# 216     yes  adult          5279441         38.0   76.0              18.0
# 214     yes  adult           529135         37.8   40.0              12.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# 218                cool          reduced   pale_cyanotic
# 129                cool           normal     normal_pink
# 76                 cool          reduced     normal_pink
# 20               normal           normal      bright_red
# 148                cool           normal     normal_pink
# 243              normal          reduced     bright_pink
# 261                cool           normal     normal_pink
# 229                cool          reduced     normal_pink
# 3                  cold           normal   dark_cyanotic
# 281                cool           absent      bright_red
# 262                cool           normal       pale_pink
# 28                 cool           normal     normal_pink
# 207                cool          reduced      bright_red
# 174                cool           normal     normal_pink
# 26                 cold          reduced       pale_pink
# 121                cool           normal   dark_cyanotic
# 74                 cool           normal     normal_pink
# 10                 cool          reduced      bright_red
# 216                cool           normal     normal_pink
# 214              normal           normal     normal_pink
#
#     capillary_refill_time   ...    packed_cell_volume total_protein  \
# 218            less_3_sec   ...                  37.0           8.1
# 129            less_3_sec   ...                  44.0           7.6
# 76             less_3_sec   ...                  37.0          68.0
# 20             more_3_sec   ...                  46.0           6.1
# 148            less_3_sec   ...                  34.0          63.0
# 243            less_3_sec   ...                  47.0           8.0
# 261            less_3_sec   ...                  35.0           5.9
# 229            less_3_sec   ...                  45.0           7.5
# 3              more_3_sec   ...                  48.0           7.2
# 281            more_3_sec   ...                  60.0           7.5
# 262            more_3_sec   ...                  48.0           7.4
# 28             less_3_sec   ...                  45.0           7.5
# 207            more_3_sec   ...                  64.0          89.0
# 174            less_3_sec   ...                  45.0           7.5
# 26             more_3_sec   ...                  43.0           7.0
# 121            more_3_sec   ...                  67.0          10.2
# 74             less_3_sec   ...                  37.0           4.9
# 10             less_3_sec   ...                  44.0           6.0
# 216            more_3_sec   ...                  71.0          11.0
# 214            less_3_sec   ...                  38.0           7.0
#
#     abdomo_appearance abdomo_protein     outcome  surgical_lesion lesion_1  \
# 218            cloudy            2.3       lived              yes     2111
# 129            cloudy            2.3       lived              yes     2206
# 76             cloudy            2.3       lived              yes     3205
# 20             cloudy            2.3       lived              yes     2111
# 148            cloudy            2.3       lived               no        0
# 243             clear            2.3       lived              yes     9400
# 261            cloudy            2.3       lived               no        0
# 229            cloudy            2.3       lived              yes     2124
# 3       serosanguious            5.3        died              yes     2208
# 281            cloudy            2.3        died              yes     1400
# 262     serosanguious            3.2        died              yes    12208
# 28             cloudy            2.3        died               no     4300
# 207            cloudy            2.3  euthanized              yes     3205
# 174            cloudy            2.3       lived              yes     2208
# 26             cloudy            3.9       lived              yes     3111
# 121            cloudy            1.0  euthanized              yes     2208
# 74             cloudy            2.3        died              yes    11124
# 10             cloudy            3.6       lived              yes     2124
# 216            cloudy            2.3       lived              yes     2209
# 214            cloudy            2.3       lived              yes     3111
#
#     lesion_2  lesion_3  cp_data
# 218        0         0       no
# 129        0         0       no
# 76         0         0       no
# 20         0         0       no
# 148        0         0       no
# 243        0         0      yes
# 261        0         0       no
# 229        0         0       no
# 3          0         0      yes
# 281        0         0       no
# 262        0         0      yes
# 28         0         0       no
# 207        0         0       no
# 174        0         0       no
# 26         0         0      yes
# 121        0         0       no
# 74         0         0       no
# 10         0         0      yes
# 216        0         0      yes
# 214        0         0       no
#
# [20 rows x 28 columns]

# %%
df_horse_one_hot = pd.get_dummies(df_horse.drop(columns = ['outcome']))

# %%
df_horse_one_hot.head()
# Out:
#      hospital_number  rectal_temp  pulse  respiratory_rate  \
# 218           529736         38.2   52.0              28.0
# 129           527698         38.4   49.0              25.0
# 76            534615         37.6   38.0              20.0
# 20            530157         39.9   72.0              60.0
# 148           535314         38.7   48.0              24.0
#
#      nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 218                    5.0                37.0            8.1             2.3
# 129                    5.0                44.0            7.6             2.3
# 76                     5.0                37.0           68.0             2.3
# 20                     5.0                46.0            6.1             2.3
# 148                    5.0                34.0           63.0             2.3
#
#      lesion_1  lesion_2     ...       abdomen_firm  abdomen_normal  \
# 218      2111         0     ...                  0               0
# 129      2206         0     ...                  0               0
# 76       3205         0     ...                  0               0
# 20       2111         0     ...                  0               0
# 148         0         0     ...                  0               0
#
#      abdomen_other  abdomo_appearance_clear  abdomo_appearance_cloudy  \
# 218              0                        0                         1
# 129              0                        0                         1
# 76               0                        0                         1
# 20               0                        0                         1
# 148              0                        0                         1
#
#      abdomo_appearance_serosanguious  surgical_lesion_no  surgical_lesion_yes  \
# 218                                0                   0                    1
# 129                                0                   0                    1
# 76                                 0                   0                    1
# 20                                 0                   0                    1
# 148                                0                   1                    0
#
#      cp_data_no  cp_data_yes
# 218           1            0
# 129           1            0
# 76            1            0
# 20            1            0
# 148           1            0
#
# [5 rows x 67 columns]

# %%
X = df_horse_one_hot

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
le.fit(df_horse['outcome'])
# Out:
# LabelEncoder()

# %% [markdown]
# * Lived: 1
# * euthanized: 0
# * Died: -1

# %%
y = le.transform(df_horse['outcome']) - 1

# %% [markdown]
# ## Run ML

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB

# %%
names = ["OneR", "Nearest Neighbors", "Nearest Neighbors", "Linear SVM", "RBF SVM",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost", "Naive Bayes"]

# %%
classifiers = [
    DecisionTreeClassifier(max_depth=1),
    KNeighborsClassifier(3),
    KNeighborsClassifier(5),
    SVC(kernel="linear", C=0.025),
    SVC(kernel="rbf", C=0.025),
    DecisionTreeClassifier(max_depth=10),
    RandomForestClassifier(max_depth=10, n_estimators=3000),
    MLPClassifier(alpha=1, hidden_layer_sizes = (100, 50)),
    AdaBoostClassifier(n_estimators = 300),
    GaussianNB()]

# %% [markdown]
# ## CV

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import precision_recall_fscore_support

# %%
evaluations = []

for name, clf in zip(names, classifiers):
    y_pred = cross_val_predict(clf, X, y, cv = 10)
    precision_recall_f1 = precision_recall_fscore_support(y, y_pred, average='weighted')
    scores = cross_validate(clf, X, y, cv = 10)
    evaluations.append([name, scores['test_score'].mean(), precision_recall_f1[:3]])
# Out:
# C:\Users\JSY\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\JSY\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\JSY\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Result

# %%
evaluations.sort(key = lambda evaluations: evaluations[1])
evaluations.reverse()

# %%
for evaluation in evaluations:
    print("-----" * 5)
    print(evaluation[0])
    print("Accuracy: ", evaluation[1])
    if len(evaluation) > 2: print("Precision, Recall, F1", evaluation[2])
    print("-----" * 5, end = "\n\n")
# Out:
# -------------------------
# Random Forest
# Accuracy:  0.7098569839504212
# Precision, Recall, F1 (0.6816360344880488, 0.7023411371237458, 0.6734355278088625)
# -------------------------
#
# -------------------------
# AdaBoost
# Accuracy:  0.6478910429577838
# Precision, Recall, F1 (0.6454849498327759, 0.6454849498327759, 0.6454849498327759)
# -------------------------
#
# -------------------------
# OneR
# Accuracy:  0.621424069071455
# Precision, Recall, F1 (0.5127142128833407, 0.6220735785953178, 0.5505776787256426)
# -------------------------
#
# -------------------------
# Nearest Neighbors
# Accuracy:  0.6089731977329307
# Precision, Recall, F1 (0.6124166820114262, 0.6086956521739131, 0.6083620395861259)
# -------------------------
#
# -------------------------
# Linear SVM
# Accuracy:  0.5961012235817574
# Precision, Recall, F1 (0.4835478531130705, 0.5953177257525084, 0.4501879906149524)
# -------------------------
#
# -------------------------
# RBF SVM
# Accuracy:  0.5957556014619417
# Precision, Recall, F1 (0.3544031945951388, 0.5953177257525084, 0.4443042146077421)
# -------------------------
#
# -------------------------
# Decision Tree
# Accuracy:  0.5951726786376397
# Precision, Recall, F1 (0.6429751011261834, 0.6287625418060201, 0.634553022075946)
# -------------------------
#
# -------------------------
# Nearest Neighbors
# Accuracy:  0.5914855130038666
# Precision, Recall, F1 (0.5834548021955497, 0.5919732441471572, 0.5862242903309568)
# -------------------------
#
# -------------------------
# Neural Net
# Accuracy:  0.43027543831770754
# Precision, Recall, F1 (0.4526779652524645, 0.41471571906354515, 0.4302633362517569)
# -------------------------
#
# -------------------------
# Naive Bayes
# Accuracy:  0.29603474760315696
# Precision, Recall, F1 (0.56323696566764, 0.2976588628762542, 0.19041129658085093)
# -------------------------
